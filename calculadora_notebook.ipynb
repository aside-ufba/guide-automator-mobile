# %%
from guide_mobile import *

# %% [markdown]
# ## Manual Calculadora
# Está é a calculadora do **Android**.

# %%
init()
takeScreenshot()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x1440 at 0x7F93FE6660F0>

# %% [markdown]
# Ela é divida em duas partes:
# #### Display

# %%
takeScreenshotElement('display')
# Out:
# <PIL.Image.Image image mode=RGBA size=720x456 at 0x7F93FE657DD8>

# %% [markdown]
# #### Teclado

# %%
highlightElement('pad_numeric, pad_operator')
# Out:
# <PIL.Image.Image image mode=RGB size=720x1440 at 0x7F940C25C198>

# %% [markdown]
# Além disso no teclado número é possível deslizar a **flecha** para a esquerda, para visulização de operações matemáticas  mais complexas.

# %%
highlightElement('arrow')
move_to_direction('arrow', 'digit_2')
takeScreenshot()
quit()
# Out:
# <PIL.Image.Image image mode=RGB size=720x1440 at 0x7F93FD035DD8>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x1440 at 0x7F93FD0555F8>
