# %%
from guide_mobile import *

# %% [markdown]
# Teste **jypter**

# %%
init()

setLandscapeOrientation()

takeScreenshot()

setPortraitOrientation()

takeScreenshot()

quit()
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1440x720 at 0x7FE1934A9DA0>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=720x1440 at 0x7FE191E776D8>
